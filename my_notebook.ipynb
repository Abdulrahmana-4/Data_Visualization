# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
steam_filepath="/kaggle/input/steam-games-dataset/dataset.csv"
steam_data=pd.read_csv(steam_filepath, index_col="year")

# %%
steam_data
# Out:
#              id                                               name  \
# year
# 2011.0    96000                                The Tiny Bang Story
# 2014.0   262410                     World of Guns: Gun Disassembly
# 2020.0  1250410  Microsoft Flight Simulator 40th Anniversary Ed...
# 2015.0   365450                                            Hacknet
# 2011.0    92800                                          SpaceChem
# ...         ...                                                ...
# 2017.0   521720                                   Uncharted Waters
# 2010.0    34311                                     Kid Chameleon™
# 2010.0    34289                                   Fatal Labyrinth™
# 2017.0   628150                              Sangokushi Eiketsuden
# 2017.0   660570           Million Arthur VR: Character Command RPG
#
#         metacritic_rating  reviewer_rating  positivity_ratio  to_beat_main  \
# year
# ...

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=steam_data['positivity_ratio'], label=['positivity_ratio'])
# Out:
# <Axes: xlabel='year', ylabel='positivity_ratio'>
